# %%
import ollama

# %%
response = ollama.generate(
    model="llama3.2:1b",
    prompt="Write a poem about the beauty of nature.",
)

# %%
print(response.response)
# Out:
# In twilight's hush, where shadows play,
# The forest whispers secrets gray.
# The trees, like sentinels of old,
# Stand guard, their branches yet untold.
#
# Their leaves, a rustling, golden hue,
# As sunset's warmth begins to accrue.
# The wind stirs, and the air is bright,
# With scents of earth and flowers in sight.
#
# In mountains high, where peaks ascend,
# The air is crisp, and winds do mend.
# The snow, a blanket soft and white,
# Falls gently down, a gentle night.
#
# In oceans blue, where waves crash free,
# The tide sings sweet melodies.
# Seagulls soar, their cries so clear,
# As sunbeams dance, and stars appear.
#
# The beauty of nature's grand design,
# A symphony that echoes in time.
# A reflection of the soul's deep core,
# A treasure trove, forever more.
#
# So let us marvel at this sight,
# And cherish every moment of light.
# For in nature's splendor we are free,
# To breathe, to roam, and be.

# %%
stream = ollama.generate(model="llama3.2:1b", 
    prompt = "Write a poem about butter garlic lobster roll",
    stream = True)

for chunk in stream:
    print(f"\n\n {chunk.response}")
# Out:
#  S
#
#
#  av
#
#
#  ory
#
#
#   delights
#
#
#   of
#
#
#   the
#
#
#   sea
#
#
#  ,
#
#
#
#  A
#
#
#   culinary
#
#
#   dream
#
#
#  ,
#
#
#   for
#
#
#   you
#
#
#   and
#
#
#   me
#
#
#  .
#
#
#
#  But
#
#
#  ter
#
#
#  ,
#
#
#   garlic
#
#
#  ,
#
#
#   and
#
#
#   lobster
#
#
#  's
#
#
#   sweet
#
#
#   bite
#
#
#  ,
#
#
#
#  D
#
#
#  ance
#
#
#   on
#
#
#   tongues
#
#
#  ,
#
#
#   a
#
#
#   true
#
#
#   gastr
#
#
#  onomic
#
#
#   sight
#
#
#  .
#
#
#
#
#  The
#
#
#   b
#
#
#  rio
#
#
#  che
#
#
#   bun
#
#
#  ,
#
#
#   soft
#
#
#   and
#
#
#   divine
#
#
#  ,
#
#
#
#  A
#
#
#   gentle
#
#
#   cr
#
#
#  adle
#
#
#  ,
#
#
#   for
#
#
#   the
#
#
#   flavors
#
#
#   to
#
#
#   shine
#
#
#  .
#
#
#
#  The
#
#
#   butter
#
#
#   melts
#
#
#  ,
#
#
#   a
#
#
#   rich
#
#
#   and
#
#
#   creamy
#
#
#   stream
#
#
#  ,
#
#
#
#  That
#
#
#   coats
#
#
#   the
#
#
#   lobster
#
#
#  ,
#
#
#   in
#
#
#   its
#
#
#   vel
#
#
#  v
#
#
#  ety
#
#
#   dream
#
#
#  .
#
#
#
#
#  Gar
#
#
#  lic
#
#
#  's
#
#
#   p
#
#
#  ung
#
#
#  ent
#
#
#   zest
#
#
#  ,
#
#
#   a
#
#
#   subtle
#
#
#   delight
#
#
#  ,
#
#
#
#  Adds
#
#
#   depth
#
#
#   and
#
#
#   complexity
#
#
#  ,
#
#
#   to
#
#
#   this
#
#
#   summer
#
#
#  's
#
#
#   night
#
#
#  .
#
#
#
#  The
#
#
#   aroma
#
#
#   wa
#
#
#  fts
#
#
#  ,
#
#
#   a
#
#
#   mouth
#
#
#  water
#
#
#  ing
#
#
#   treat
#
#
#  ,
#
#
#
#  That
#
#
#   beck
#
#
#  ons
#
#
#   us
#
#
#  ,
#
#
#   to
#
#
#   take
#
#
#   a
#
#
#   savory
#
#
#   seat
#
#
#  .
#
#
#
#
#  As
#
#
#   we
#
#
#   take
#
#
#   our
#
#
#   first
#
#
#   bite
#
#
#  ,
#
#
#   oh
#
#
#   what
#
#
#   a
#
#
#   thrill
#
#
#  ,
#
#
#
#  The
#
#
#   flavors
#
#
#   meld
#
#
#  ,
#
#
#   in
#
#
#   a
#
#
#   culinary
#
#
#   fulfill
#
#
#  .
#
#
#
#  The
#
#
#   lobster
#
#
#  's
#
#
#   tender
#
#
#   flesh
#
#
#  ,
#
#
#   the
#
#
#   garlic
#
#
#  's
#
#
#   zest
#
#
#  ,
#
#
#
#  Combine
#
#
#   in
#
#
#   harmony
#
#
#  ,
#
#
#   in
#
#
#   a
#
#
#   true
#
#
#   gastr
#
#
#  onomic
#
#
#   nest
#
#
#  .
#
#
#
#
#  So
#
#
#   here
#
#
#  's
#
#
#   to
#
#
#   the
#
#
#   butter
#
#
#   garlic
#
#
#   lobster
#
#
#   roll
#
#
#  ,
#
#
#
#  A
#
#
#   dish
#
#
#   divine
#
#
#  ,
#
#
#   that
#
#
#   makes
#
#
#   us
#
#
#   whole
#
#
#  .
#
#
#
#  It
#
#
#  's
#
#
#   a
#
#
#   taste
#
#
#   of
#
#
#   summer
#
#
#  ,
#
#
#   on
#
#
#   a
#
#
#   plate
#
#
#   so
#
#
#   fine
#
#
#  ,
#
#
#
#  A
#
#
#   culinary
#
#
#   joy
#
#
#  ,
#
#
#   that
#
#
#  's
#
#
#   simply
#
#
#   sublime
#
#
#  .
